# %% [markdown]
# # No More Alzheimer's Disease

# %% [markdown]
# ## General Data Processing

# %% [markdown]
# ### Data Downloading

# %%
import sys
fields_to_drop = ['RID', 'VISCODE']

# %% [markdown]
# ### SVM Approach
#
# Use Cross Validation to find what parameters suit this problem the best

# %%
# %reload_ext autoreload
# %autoreload 2
sys.path.append("../../../../..")
from Classifiers.MySVM import MySVM

# %%
svm = MySVM("data.csv", fields_to_drop)
svm.hyper_parameter_selection()
# Out:
# Best Parameters:  {'C': 1000, 'decision_function_shape': 'ovr', 'degree': 2, 'kernel': 'rbf'}
# Best Score:  0.7515290519877675

# %% [markdown]
# ## Test for these hyper-parameters

# %%
svm.test(True)
# Out:
# Accuracy is 0.7370030581039755
# +-----------+----------+----------+----------+
# |           |      SCD |      MCI |       AD |
# +===========+==========+==========+==========+
# | Recall    | 0.828829 | 0.482456 | 0.921569 |
# +-----------+----------+----------+----------+
# | Precision | 0.676471 | 0.705128 | 0.831858 |
# +-----------+----------+----------+----------+
# | F1 Score  | 0.744939 | 0.572917 | 0.874419 |
# +-----------+----------+----------+----------+

# %% [markdown]
# # Random Forest Approach

# %%
# %reload_ext autoreload
# %autoreload 2
from Classifiers.MyRF import MyRF

# %%
# Before Removing Outliers
print("Computing Results.......")
rf = MyRF("data.csv", fields_to_drop)
rf.hyper_parameter_selection()
# Out:
# Computing Results.......
# Best Parameters:  {'bootstrap': True, 'class_weight': 'balanced', 'criterion': 'entropy', 'max_depth': 20, 'max_features': 'sqrt', 'min_samples_split': 2, 'n_estimators': 150}
# Best Score:  0.6843325582179086
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[12], line 4
#       2 print("Computing Results.......")
#       3 rf = MyRF("data.csv", fields_to_drop)
# ----> 4 rf.hyper_parameter_selection()
#
# File d:\Git\NoMoreAlzheimersDisease\PreProcessingFiles\Data\PreProcessedData\File2\UnCleanData\../../../../..\Classifiers\MyRF.py:45, in MyRF.hyper_parameter_selection(self, verbose)
#      41 # Store these values for next function
#      43 self.grid_search = grid_search
# ---> 45 super().display_hyperparameter_results(self.grid_search, self.parameters, self.param_grid)
#
# File d:\Git\NoMoreAlzheimersDisease\PreProcessingFiles\Data\PreProcessedData\File2\UnCleanData\../../../../..\Classifiers\MyClassifier.py:45, in MyClassifier.display_hyperparameter_results(self, grid_search, parameters, param_grid)
#      43 if i == len(parameters):
#      44     break
# ---> 45 temp = results.groupby('param_' + parameters[i])['mean_test_score']
#      46 ax.plot(param_grid[parameters[i]], temp.mean(), color='blue', marker='o')
#      47 ax.errorbar(param_grid[parameters[i]], temp.mean(), yerr=temp.std(), color='orange')
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\pandas\core\frame.py:8869, in DataFrame.groupby(self, by, axis, level, as_index, sort, group_keys, observed, dropna)
#    8866 if level is None and by is None:
#    8867     raise TypeError("You have to supply one of 'by' and 'level'")
# -> 8869 return DataFrameGroupBy(
#    8870     obj=self,
#    8871     keys=by,
#    8872     axis=axis,
#    8873     level=level,
#    8874     as_index=as_index,
#    8875     sort=sort,
#    8876     group_keys=group_keys,
#    8877     observed=observed,
#    8878     dropna=dropna,
#    8879 )
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\pandas\core\groupby\groupby.py:1278, in GroupBy.__init__(self, obj, keys, axis, level, grouper, exclusions, selection, as_index, sort, group_keys, observed, dropna)
#    1275 self.dropna = dropna
#    1277 if grouper is None:
# -> 1278     grouper, exclusions, obj = get_grouper(
#    1279         obj,
#    1280         keys,
#    1281         axis=axis,
#    1282         level=level,
#    1283         sort=sort,
#    1284         observed=False if observed is lib.no_default else observed,
#    1285         dropna=self.dropna,
#    1286     )
#    1288 if observed is lib.no_default:
#    1289     if any(ping._passed_categorical for ping in grouper.groupings):
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\pandas\core\groupby\grouper.py:1009, in get_grouper(obj, key, axis, level, sort, observed, validate, dropna)
#    1007         in_axis, level, gpr = False, gpr, None
#    1008     else:
# -> 1009         raise KeyError(gpr)
#    1010 elif isinstance(gpr, Grouper) and gpr.key is not None:
#    1011     # Add key to exclusions
#    1012     exclusions.add(gpr.key)
#
# KeyError: 'param_crierion'

# %%
# Display the test results for this data
rf.test(True)
# Out:
# Accuracy is 0.7828746177370031
# +-----------+----------+----------+----------+
# |           |      SCD |      MCI |       AD |
# +===========+==========+==========+==========+
# | Recall    | 0.774775 | 0.640351 | 0.95098  |
# +-----------+----------+----------+----------+
# | Precision | 0.761062 | 0.708738 | 0.873874 |
# +-----------+----------+----------+----------+
# | F1 Score  | 0.767857 | 0.672811 | 0.910798 |
# +-----------+----------+----------+----------+

# %% [markdown]
# ## Relative Feature Importances

# %%
# Get the importance of each feature in this classifier
rf.relative_importance()
