# %% [markdown]
# # No More Alzheimer's Disease

# %% [markdown]
# ## General Data Processing

# %% [markdown]
# ### Data Downloading

# %%
import sys
fields_to_drop = ['RID', 'VISCODE', 'MMSE', 'PTEDUCAT', 'AGE']

# %% [markdown]
# ### SVM Approach
#
# Use Cross Validation to find what parameters suit this problem the best

# %%
# %reload_ext autoreload
# %autoreload 2
sys.path.append("../../../../..")
from Classifiers.MySVM import MySVM

# %%
svm = MySVM("data.csv", fields_to_drop)
svm.hyper_parameter_selection()
# Out:
# Best Parameters:  {'C': 100, 'decision_function_shape': 'ovr', 'degree': 2, 'kernel': 'rbf'}
# Best Score:  0.4901960784313726

# %% [markdown]
# ## Test for these hyper-parameters

# %%
svm.test(True)
# Out:
# Accuracy is 0.45555555555555555
# +-----------+----------+----------+----------+
# |           |      SCD |      MCI |       AD |
# +===========+==========+==========+==========+
# | Recall    | 0.6      | 0.5      | 0.258065 |
# +-----------+----------+----------+----------+
# | Precision | 0.636364 | 0.285714 | 0.533333 |
# +-----------+----------+----------+----------+
# | F1 Score  | 0.617647 | 0.363636 | 0.347826 |
# +-----------+----------+----------+----------+

# %% [markdown]
# # Random Forest Approach

# %%
# %reload_ext autoreload
# %autoreload 2
from Classifiers.MyRF import MyRF

# %%
# Before Removing Outliers
print("Computing Results.......")
rf = MyRF("data.csv", fields_to_drop)
rf.hyper_parameter_selection()
# Out:
# Computing Results.......
# Best Parameters:  {'bootstrap': True, 'class_weight': 'balanced', 'criterion': 'log_loss', 'n_estimators': 50}
# Best Score:  0.45098039215686275

# %%
# Display the test results for this data
rf.test(True)
# Out:
# Accuracy is 0.4888888888888889
# +-----------+----------+----------+----------+
# |           |      SCD |      MCI |       AD |
# +===========+==========+==========+==========+
# | Recall    | 0.714286 | 0.25     | 0.419355 |
# +-----------+----------+----------+----------+
# | Precision | 0.625    | 0.24     | 0.52     |
# +-----------+----------+----------+----------+
# | F1 Score  | 0.666667 | 0.244898 | 0.464286 |
# +-----------+----------+----------+----------+

# %% [markdown]
# ## Relative Feature Importances

# %%
# Get the importance of each feature in this classifier
rf.relative_importance()
