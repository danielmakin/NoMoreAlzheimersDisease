# %% [markdown]
# # No More Alzheimer's Disease

# %% [markdown]
# ## General Data Processing

# %% [markdown]
# ### Data Downloading

# %%
# THIS FILE IS NOT DONE YET (Or the other one)
import sys
fields_to_drop = ['RID', 'VISCODE', 'MMSE', 'PTEDUCAT', 'AGE']

# %% [markdown]
# ### SVM Approach
#
# Use Cross Validation to find what parameters suit this problem the best

# %%
# %reload_ext autoreload
# %autoreload 2
sys.path.append("../../../../..")
from Classifiers.MySVM import MySVM

# %%
svm = MySVM("data.csv", fields_to_drop)
svm.hyper_parameter_selection()
# Out:
# Best Parameters:  {'C': 1000, 'decision_function_shape': 'ovr', 'degree': 2, 'kernel': 'rbf'}
# Best Score:  0.5256547874624302

# %% [markdown]
# ## Test for these hyper-parameters

# %%
svm.test(True)
# Out:
# Accuracy is 0.42718446601941745
# +-----------+----------+----------+----------+
# |           |      SCD |      MCI |       AD |
# +===========+==========+==========+==========+
# | Recall    | 0.542857 | 0.361111 | 0.375    |
# +-----------+----------+----------+----------+
# | Precision | 0.452381 | 0.393939 | 0.428571 |
# +-----------+----------+----------+----------+
# | F1 Score  | 0.493506 | 0.376812 | 0.4      |
# +-----------+----------+----------+----------+

# %% [markdown]
# # Random Forest Approach

# %%
# %reload_ext autoreload
# %autoreload 2
from Classifiers.MyRF import MyRF

# %%
# Before Removing Outliers
print("Computing Results.......")
rf = MyRF("data.csv", fields_to_drop)
rf.hyper_parameter_selection()
# Out:
# Computing Results.......
# Best Parameters:  {'bootstrap': True, 'class_weight': 'balanced_subsample', 'criterion': 'entropy', 'n_estimators': 300}
# Best Score:  0.48658222413052815

# %%
# Display the test results for this data
rf.test(True)
# Out:
# Accuracy is 0.3592233009708738
# +-----------+----------+----------+----------+
# |           |      SCD |      MCI |       AD |
# +===========+==========+==========+==========+
# | Recall    | 0.4      | 0.305556 | 0.375    |
# +-----------+----------+----------+----------+
# | Precision | 0.368421 | 0.34375  | 0.363636 |
# +-----------+----------+----------+----------+
# | F1 Score  | 0.383562 | 0.323529 | 0.369231 |
# +-----------+----------+----------+----------+

# %% [markdown]
# ## Relative Feature Importances

# %%
# Get the importance of each feature in this classifier
rf.relative_importance()
