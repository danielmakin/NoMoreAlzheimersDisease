# %% [markdown]
# # No More Alzheimer's Disease

# %% [markdown]
# ## General Data Processing

# %% [markdown]
# ### Data Downloading

# %%
import sys
fields_to_drop = ['VISCODE', 'RID']

# %% [markdown]
# ### SVM Approach
#
# Use Cross Validation to find what parameters suit this problem the best

# %%
# %reload_ext autoreload
# %autoreload 2
sys.path.append("../../../../..")
from Classifiers.MySVM import MySVM

# %%
svm = MySVM("data.csv", fields_to_drop)
svm.hyper_parameter_selection()
# Out:
# Best Parameters:  {'C': 1, 'decision_function_shape': 'ovr', 'degree': 3, 'kernel': 'poly'}
# Best Score:  0.704164877629884

# %% [markdown]
# ## Test for these hyper-parameters

# %%
svm.test(True)
# Out:
# Accuracy is 0.6893203883495146
# +-----------+----------+----------+----------+
# |           |      SCD |      MCI |       AD |
# +===========+==========+==========+==========+
# | Recall    | 0.885714 | 0.472222 | 0.71875  |
# +-----------+----------+----------+----------+
# | Precision | 0.673913 | 0.586207 | 0.821429 |
# +-----------+----------+----------+----------+
# | F1 Score  | 0.765432 | 0.523077 | 0.766667 |
# +-----------+----------+----------+----------+

# %% [markdown]
# # Random Forest Approach

# %%
# %reload_ext autoreload
# %autoreload 2
from Classifiers.MyRF import MyRF

# %%
# Before Removing Outliers
print("Computing Results.......")
rf = MyRF("data.csv", fields_to_drop)
rf.hyper_parameter_selection()
# Out:
# Computing Results.......
# Best Parameters:  {'bootstrap': True, 'class_weight': 'balanced_subsample', 'criterion': 'log_loss', 'n_estimators': 250}
# Best Score:  0.7188886503506513

# %%
# Display the test results for this data
rf.test(True)
# Out:
# Accuracy is 0.7087378640776699
# +-----------+----------+----------+----------+
# |           |      SCD |      MCI |       AD |
# +===========+==========+==========+==========+
# | Recall    | 0.828571 | 0.555556 | 0.75     |
# +-----------+----------+----------+----------+
# | Precision | 0.805556 | 0.606061 | 0.705882 |
# +-----------+----------+----------+----------+
# | F1 Score  | 0.816901 | 0.57971  | 0.727273 |
# +-----------+----------+----------+----------+

# %% [markdown]
# ## Relative Feature Importances

# %%
# Get the importance of each feature in this classifier
rf.relative_importance()
