# %% [markdown]
# # No More Alzheimer's Disease

# %% [markdown]
# ## General Data Processing

# %% [markdown]
# ### Data Downloading

# %%
import sys
fields_to_drop = []

# %% [markdown]
# ### SVM Approach
#
# Use Cross Validation to find what parameters suit this problem the best

# %%
# %reload_ext autoreload
# %autoreload 2
sys.path.append("../../../../..")
from Classifiers.MySVM import MySVM

# %%
svm = MySVM("data.csv", fields_to_drop)
svm.hyper_parameter_selection()
# Out:
# Best Parameters:  {'C': 1000, 'decision_function_shape': 'ovr', 'degree': 4, 'kernel': 'poly'}
# Best Score:  0.7030812324929973

# %% [markdown]
# ## Test for these hyper-parameters

# %%
svm.test(True)
# Out:
# Accuracy is 0.6111111111111112
# +-----------+-------+----------+----------+
# |           |   SCD |      MCI |       AD |
# +===========+=======+==========+==========+
# | Recall    |   0.8 | 0.458333 | 0.516129 |
# +-----------+-------+----------+----------+
# | Precision |   0.8 | 0.333333 | 0.727273 |
# +-----------+-------+----------+----------+
# | F1 Score  |   0.8 | 0.385965 | 0.603774 |
# +-----------+-------+----------+----------+

# %% [markdown]
# # Random Forest Approach

# %%
# %reload_ext autoreload
# %autoreload 2
from Classifiers.MyRF import MyRF

# %%
# Before Removing Outliers
print("Computing Results.......")
rf = MyRF("data.csv", fields_to_drop)
rf.hyper_parameter_selection()
# Out:
# Computing Results.......
# Best Parameters:  {'bootstrap': True, 'class_weight': 'balanced_subsample', 'criterion': 'entropy', 'n_estimators': 150}
# Best Score:  0.7030812324929973

# %%
# Display the test results for this data
rf.test(True)
# Out:
# Accuracy is 0.6
# +-----------+----------+----------+----------+
# |           |      SCD |      MCI |       AD |
# +===========+==========+==========+==========+
# | Recall    | 0.771429 | 0.5      | 0.483871 |
# +-----------+----------+----------+----------+
# | Precision | 0.84375  | 0.333333 | 0.681818 |
# +-----------+----------+----------+----------+
# | F1 Score  | 0.80597  | 0.4      | 0.566038 |
# +-----------+----------+----------+----------+

# %% [markdown]
# ## Relative Feature Importances

# %%
# Get the importance of each feature in this classifier
rf.relative_importance()
