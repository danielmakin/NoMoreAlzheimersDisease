# %% [markdown]
# # No More Alzheimer's Disease

# %% [markdown]
# ## General Data Processing

# %% [markdown]
# ### Data Downloading

# %%
import sys
fields_to_drop = []

# %% [markdown]
# ### SVM Approach
#
# Use Cross Validation to find what parameters suit this problem the best

# %%
# %reload_ext autoreload
# %autoreload 2
sys.path.append("../../../../..")
from Classifiers.MySVM import MySVM

# %%
svm = MySVM("data.csv", fields_to_drop)
svm.hyper_parameter_selection()
# Out:
# Best Parameters:  {'C': 10, 'decision_function_shape': 'ovr', 'degree': 2, 'kernel': 'rbf'}
# Best Score:  0.7016129032258065

# %% [markdown]
# ## Test for these hyper-parameters

# %%
svm.test(True)
# Out:
# Accuracy is 0.7204301075268817
# +-----------+----------+----------+----------+
# |           |      SCD |      MCI |       AD |
# +===========+==========+==========+==========+
# | Recall    | 0.806452 | 0.6      | 0.72973  |
# +-----------+----------+----------+----------+
# | Precision | 0.714286 | 0.517241 | 0.931034 |
# +-----------+----------+----------+----------+
# | F1 Score  | 0.757576 | 0.555556 | 0.818182 |
# +-----------+----------+----------+----------+

# %% [markdown]
# # Random Forest Approach

# %%
# %reload_ext autoreload
# %autoreload 2
from Classifiers.MyRF import MyRF

# %%
# Before Removing Outliers
print("Computing Results.......")
rf = MyRF("data.csv", fields_to_drop)
rf.hyper_parameter_selection()
# Out:
# Computing Results.......
# Best Parameters:  {'bootstrap': False, 'class_weight': 'balanced_subsample', 'criterion': 'gini', 'n_estimators': 100}
# Best Score:  0.6827956989247311

# %%
# Display the test results for this data
rf.test(True)
# Out:
# Accuracy is 0.6989247311827957
# +-----------+----------+----------+----------+
# |           |      SCD |      MCI |       AD |
# +===========+==========+==========+==========+
# | Recall    | 0.741935 | 0.48     | 0.810811 |
# +-----------+----------+----------+----------+
# | Precision | 0.821429 | 0.444444 | 0.789474 |
# +-----------+----------+----------+----------+
# | F1 Score  | 0.779661 | 0.461538 | 0.8      |
# +-----------+----------+----------+----------+

# %% [markdown]
# ## Relative Feature Importances

# %%
# Get the importance of each feature in this classifier
rf.relative_importance()
