# %% [markdown]
# # No More Alzheimer's Disease

# %% [markdown]
# ## General Data Processing

# %% [markdown]
# ### Data Downloading

# %%
import sys
fields_to_drop = ['MMSE', 'PTEDUCAT', 'AGE']

# %% [markdown]
# ### SVM Approach
#
# Use Cross Validation to find what parameters suit this problem the best

# %%
# %reload_ext autoreload
# %autoreload 2
sys.path.append("../../../../..")
from Classifiers.MySVM import MySVM

# %%
svm = MySVM("data.csv", fields_to_drop)
svm.hyper_parameter_selection()
# Out:
# Best Parameters:  {'C': 1, 'decision_function_shape': 'ovr', 'degree': 2, 'kernel': 'rbf'}
# Best Score:  0.47580645161290325

# %% [markdown]
# ## Test for these hyper-parameters

# %%
svm.test(True)
# Out:
# Accuracy is 0.5483870967741935
# +-----------+----------+----------+----------+
# |           |      SCD |      MCI |       AD |
# +===========+==========+==========+==========+
# | Recall    | 0.774194 | 0.32     | 0.513514 |
# +-----------+----------+----------+----------+
# | Precision | 0.533333 | 0.4      | 0.678571 |
# +-----------+----------+----------+----------+
# | F1 Score  | 0.631579 | 0.355556 | 0.584615 |
# +-----------+----------+----------+----------+

# %% [markdown]
# # Random Forest Approach

# %%
# %reload_ext autoreload
# %autoreload 2
from Classifiers.MyRF import MyRF

# %%
# Before Removing Outliers
print("Computing Results.......")
rf = MyRF("data.csv", fields_to_drop)
rf.hyper_parameter_selection()
# Out:
# Computing Results.......
# Best Parameters:  {'bootstrap': False, 'class_weight': 'balanced', 'criterion': 'entropy', 'n_estimators': 100}
# Best Score:  0.48655913978494625

# %%
# Display the test results for this data
rf.test(True)
# Out:
# Accuracy is 0.46236559139784944
# +-----------+----------+---------+----------+
# |           |      SCD |     MCI |       AD |
# +===========+==========+=========+==========+
# | Recall    | 0.645161 | 0.24    | 0.459459 |
# +-----------+----------+---------+----------+
# | Precision | 0.512821 | 0.26087 | 0.548387 |
# +-----------+----------+---------+----------+
# | F1 Score  | 0.571429 | 0.25    | 0.5      |
# +-----------+----------+---------+----------+

# %% [markdown]
# ## Relative Feature Importances

# %%
# Get the importance of each feature in this classifier
rf.relative_importance()
